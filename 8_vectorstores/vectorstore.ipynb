# %%
print("om")
# Out:
# om

# %%
from langchain_chroma import Chroma
from langchain_huggingface import HuggingFaceEmbeddings

# Simple open embedding model
embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# Create Chroma DB
vector_store = Chroma(
    embedding_function=embedding_model,
    persist_directory="my_chroma_db",
    collection_name="sample"
)

# Add texts
vector_store.add_texts([
    "AI is transforming healthcare.",
    "Football is a popular sport.",
    "Deep learning improves AI systems."
])

vector_store.persist()

print("Success 🔥 Working perfectly")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 23
#      16 # Add texts
#      17 vector_store.add_texts([
#      18     "AI is transforming healthcare.",
#      19     "Football is a popular sport.",
#      20     "Deep learning improves AI systems."
#      21 ])
# ---> 23 vector_store.persist()
#      25 print("Success 🔥 Working perfectly")
#
# AttributeError: 'Chroma' object has no attribute 'persist'
