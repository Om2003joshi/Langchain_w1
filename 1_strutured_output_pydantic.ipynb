# %% [markdown]
# ### Read readme.md first

# %%
from typing import TypedDict,Annotated,Optional,Literal

# %%
"""class soltion:
    def __init__(self) -> None:
        pass"""
# Out:
# 'class soltion:\n    def __init__(self) -> None:\n        pass'

# %%
"""# schemea
class review(TypedDict):
    summary:str
    sentiment:str
    
    """
# Out:
# '# schemea\nclass review(TypedDict):\n    summary:str\n    sentiment:str\n\n    '

# %%
from groq import Groq

# %%
"""from dotenv import load_dotenv
import os
from langchain_groq import ChatGroq

load_dotenv()

llm = ChatGroq(
    model="moonshotai/kimi-k2-instruct-0905",  # ✅ spelling fixed
    api_key=os.getenv("GROQ_API_KEY"),
    temperature=0.3,
)

response = llm.invoke("Hi")
print(response.content)
"""
# Out:
# 'from dotenv import load_dotenv\nimport os\nfrom langchain_groq import ChatGroq\n\nload_dotenv()\n\nllm = ChatGroq(\n    model="moonshotai/kimi-k2-instruct-0905",  # ✅ spelling fixed\n    api_key=os.getenv("GROQ_API_KEY"),\n    temperature=0.3,\n)\n\nresponse = llm.invoke("Hi")\nprint(response.content)\n'

# %%
import os
from google.genai import Client

# Get API key from environment variable
api_key = os.getenv("GOOGLE_API_KEY")
if not api_key:
    raise ValueError("Please set the GOOGLE_API_KEY environment variable.")

# Initialize client with the API key from env
client = Client(api_key=api_key)

# List available models
models = client.models.list()

for m in models:
    print("Name:", m.name)
    print("Display Name:", m.display_name)
    # Capabilities might contain supported generation methods
    print("Capabilities:", getattr(m, "capabilities", "N/A"))
    print("---")
# Out:
# Name: models/gemini-2.5-flash
# Display Name: Gemini 2.5 Flash
# Capabilities: N/A
# ---
# Name: models/gemini-2.5-pro
# Display Name: Gemini 2.5 Pro
# Capabilities: N/A
# ---
# Name: models/gemini-2.0-flash
# Display Name: Gemini 2.0 Flash
# Capabilities: N/A
# ---
# Name: models/gemini-2.0-flash-001
# Display Name: Gemini 2.0 Flash 001
# Capabilities: N/A
# ---
# Name: models/gemini-2.0-flash-exp-image-generation
# Display Name: Gemini 2.0 Flash (Image Generation) Experimental
# Capabilities: N/A
# ---
# Name: models/gemini-2.0-flash-lite-001
# Display Name: Gemini 2.0 Flash-Lite 001
# Capabilities: N/A
# ---
# Name: models/gemini-2.0-flash-lite
# Display Name: Gemini 2.0 Flash-Lite
# Capabilities: N/A
# ---
# Name: models/gemini-exp-1206
# Display Name: Gemini Experimental 1206
# Capabilities: N/A
# ---
# Name: models/gemini-2.5-flash-preview-tts
# Display Name: Gemini 2.5 Flash Preview TTS
# Capabilities: N/A
# ---
# Name: models/gemini-2.5-pro-preview-tts
# ...

# %%
from dotenv import load_dotenv
import os
from langchain_google_genai import ChatGoogleGenerativeAI

# Load environment variables from .env
load_dotenv()

# Initialize the LLM
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",                   # correct parameter
    google_api_key=os.environ["GOOGLE_API_KEY"],  # correct parameter
    temperature=0
)

# Send a message
response = llm.invoke("Hi")
print(response.content)
# Out:
# Hi there! How can I help you today?

# %%
# with struture output
"""1.TypedDict
2.pydantic
3.json_schema"""
# Out:
# '1.TypedDict\n2.pydantic\n3.json_schema'

# %%
# schemea
class review(TypedDict):
    summary:Annotated[str,"a brief summary of the rewview"]
    sentiment:Annotated[Literal["pos","neg"],"Return sentiment of the review rither negative,positive or nutral"]
    key_themes:Annotated[list[str],"write down all the key themes discussed in the review in list"]
    pros:Annotated[Optional[list[str]],"write down all the pros inside a list"]
    cons:Annotated[Optional[list[str]],"write down all the cons inside a list"]

# %%
str_model=llm.with_structured_output(review)

# %%
result=str_model.invoke("""There is no legal, ethical software that allows one partner to secretly spy on another partner’s PC/mobile, collect private messages/photos, and then use that data in court without consent.
Doing this illegally can backfire badly—even if the partner was cheating.""")

# %%
print(result)
# Out:
# {'summary': "It is illegal and unethical to secretly spy on a partner's PC or mobile to collect private data for use in court without consent, and doing so can have severe negative consequences.", 'sentiment': 'neg', 'key_themes': ['legality of spying', 'ethics of data collection', 'consent', 'admissibility of evidence', 'consequences of illegal actions'], 'pros': [], 'cons': ['illegal', 'unethical', 'data collected without consent', 'data not usable in court', 'can backfire badly']}
