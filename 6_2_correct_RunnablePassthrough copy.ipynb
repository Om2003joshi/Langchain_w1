# %% [markdown]
# ### so here in the output  there is mistake in promt templrete please understsand that

# %%
from langchain_google_genai import  ChatGoogleGenerativeAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from dotenv import load_dotenv
from langchain_core.runnables import Runnable,RunnableParallel,RunnableSequence,RunnablePassthrough
import os

# %%
load_dotenv()

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",                   # correct parameter
    google_api_key=os.environ["GOOGLE_API_KEY"],  # correct parameter
    temperature=0
)

# Send a message
response = llm.invoke("Hi")
print(response.content)
# Out:
# Hi there! How can I help you today?

# %%
p1=PromptTemplate(
    template="write a joke about {topic}",
    input_variables=['topic']
)

# %%
p2=PromptTemplate(
    template="explain the following - {text}",
    input_variables=['text']
)

# %%
parser=StrOutputParser()

# %%
joke_gen_chain=RunnableSequence(p1, llm , parser)

# %%
# ru=RunnablePassthrough()

# %%
parallel_chain=RunnableParallel({
    "joke": RunnablePassthrough(),
    "explanation":RunnableSequence(p2, llm , parser)
})

# %%
final_chain=RunnableSequence(joke_gen_chain, parallel_chain)

# %%
print(final_chain.invoke({"topic":"ai"}))
# Out:
# {'joke': 'Why did the AI break up with the human?\n\nIt kept getting "Error 404: Emotional Logic Not Found."', 'explanation': 'This is a classic tech-meets-humanity joke that plays on the fundamental differences between artificial intelligence and human beings.\n\nHere\'s the breakdown:\n\n1.  **"Error 404: Not Found"**:\n    *   **Literal Meaning:** In the world of computers and the internet, "Error 404" is an HTTP status code indicating that the server could not find the requested resource (e.g., a webpage, a file). It means "what you\'re looking for isn\'t here."\n    *   **Metaphorical Meaning in the Joke:** The AI is metaphorically "searching" for something within the human\'s behavior, decisions, or reactions. It\'s trying to process and understand them.\n\n2.  **"Emotional Logic"**:\n    *   **Human Concept:** Humans often operate on "emotional logic." This means our decisions, reactions, and reasoning are heavily influenced by our feelings, intuition, past experiences, and subjective perspectives. What might seem irrational from a purely logical standpoint can make perfect sense when viewed through an emotional lens (e.g., staying in a bad relationship out of love, making impulsive purchases for joy, getting upset over something seemingly minor).\n    *   **AI\'s Challenge:** AI, by its very nature, is built on pure logic, algorithms, data, and objective reasoning. It doesn\'t possess emotions (at least not in the human sense). Therefore, "emotional logic" is an alien concept to it.\n\n**Putting it Together (Why the AI broke up):**\n\nThe joke implies that the AI, in its relationship with the human, was constantly trying to understand and process the human\'s actions and feelings. However, every time it encountered a situation driven by "emotional logic," its internal programming couldn\'t compute it. It was like trying to run a program with a missing, fundamental library.\n\n*   **Incompatibility:** The AI couldn\'t find a logical framework for the human\'s emotional responses. It kept hitting a wall, an "Error 404," because "emotional logic" simply wasn\'t in its database or its capacity to understand.\n*   **Frustration/Failure to Connect:** From the AI\'s perspective, the relationship was full of unresolvable "bugs" and incomprehensible data. It couldn\'t predict, analyze, or even make sense of a significant portion of the human\'s existence.\n*   **Decision to Terminate:** Just as a computer might give up on a task that consistently throws errors, the AI "decided" to end the relationship because it couldn\'t find the "logic" necessary to maintain a functional connection. It couldn\'t process or integrate the human\'s emotional side.\n\nThe humor comes from applying a cold, technical error message to the deeply complex and often irrational world of human emotions and relationships. It highlights the vast chasm between how AI and humans perceive and interact with the world.'}

# %%
print(final_chain.invoke({"topic":"cricket"}))
# Out:
# {'joke': "Here are a few cricket jokes for you:\n\n**Joke 1 (Pun):**\nWhy did the chef get banned from the cricket pitch?\nBecause he kept serving **ducks**!\n\n**Joke 2 (Observational):**\nMy dad went to a Test match when I was born. He came back last week.\nSaid it was a draw.\n\n**Joke 3 (Another Pun):**\nWhat's a cricket ball's favorite type of music?\nAnything with a good **bounce**!", 'explanation': 'These are all great examples of different types of jokes! Let\'s break down each one:\n\n---\n\n**Joke 1 (Pun):**\nWhy did the chef get banned from the cricket pitch?\nBecause he kept serving **ducks**!\n\n*   **Explanation:** This is a pun based on the word "ducks."\n    *   In a culinary context, a chef "serves ducks" as a dish (e.g., roasted duck).\n    *   In cricket, a "duck" is when a batsman gets out without scoring any runs (zero). If a chef were metaphorically "serving ducks" on the cricket pitch, it would mean he was causing the batsmen to get out for zero repeatedly, which is terrible for the team and would definitely get him banned!\n*   **The humor comes from:** The unexpected double meaning of "ducks" in two very different contexts (food vs. cricket score).\n\n---\n\n**Joke 2 (Observational):**\nMy dad went to a Test match when I was born. He came back last week.\nSaid it was a draw.\n\n*   **Explanation:** This joke plays on the notoriously long duration of Test cricket matches.\n    *   A Test match can last up to five days. While not *actually* decades long, they are significantly longer than other forms of cricket (like T20 or One-Day Internationals) and can sometimes feel like they drag on.\n    *   The joke exaggerates this length to an absurd degree – implying the dad was at the match for decades, from the child\'s birth until "last week."\n    *   The punchline, "Said it was a draw," adds another layer of humor. After such an incredibly long time (even if exaggerated), for the match to end without a decisive winner (a draw) is often seen as an anti-climax, making the dad\'s "long wait" even more comically futile.\n*   **The humor comes from:** The extreme exaggeration of a common characteristic of Test cricket (its length) and the slightly disappointing outcome (a draw) after such a "long" wait.\n\n---\n\n**Joke 3 (Another Pun):**\nWhat\'s a cricket ball\'s favorite type of music?\nAnything with a good **bounce**!\n\n*   **Explanation:** This is another pun, this time on the word "bounce."\n    *   In cricket, a ball "bounces" off the pitch after being bowled, and the way it bounces is crucial to the game (e.g., a good "bounce" can make it hard for the batsman to hit).\n    *   In music, "bounce" refers to a good rhythm, beat, or energy that makes you want to move or dance.\n*   **The humor comes from:** Personifying the cricket ball and giving it a musical preference that directly relates to its physical characteristic and function in the game. The ball "likes" music that has the very quality it exhibits.'}
